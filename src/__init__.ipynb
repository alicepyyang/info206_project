# %%
run Recipe_main
# Out:
# Welcome To portFOODlio!
# Your own personalized recipe portfolio!
#
# Are you hungry but have no clue as to what to cook?
# No worries!
# Just provide us with the list of ingredients you would like to incorporate      in a dish and we will do the rest for you!
#
# Enter the list of ingredients (comma seperated): tomato
#
# Use the numbers to navigate the menu.
# Please choose your recipe preference.
# 1 - Category
# 2 - World Cuisine
# 3 - No Preference
# 4 - Quit
# > 1
#
# Use the numbers to navigate the menu.
# Please choose a category for your recipe.
# 1 - Appetizers And Snacks
# 2 - Breakfast And Brunch
# 3 - Main Dish
# 4 - Desserts
# 5 - Drinks
# 6 - Salad
# 7 - Fruits And Vegetables
# 8 - Side Dish
# 9 - Soups, Stews And Chili
# 10 - Go Back To Preference Selection
# 11 - Quit
# > 1
# {'category': 'Appetizers and Snacks'}
#
# Use the numbers to navigate the menu.
# 1 - View Recipes
# 2 - View Youtube Recipe
# 3 - Go Back To Category Selection
# 4 - Quit
# > 1
# ...
